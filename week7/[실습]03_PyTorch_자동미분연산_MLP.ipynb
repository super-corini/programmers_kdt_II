# %% [markdown]
# # Pytorch Tutoral - Autograd & MLP(Multi-layer perceptron)

# %% [markdown]
# # Autograd
#
# - `autograd`패키지는 텐서의 모든 연산에 대한 자동 미분을 제공
# - 실행-기반-정의(define-by-run) 프레임워크로, 코드를 어떻게 작성하여 실행하느냐에 따라 역전파가 정의된다는 것을 의미
# - 역전파는 학습 과정의 매 단계마다 달라짐

# %% [markdown]
# ## Tensor
#
# - `torch.Tensor` 클래스의 `.requires_grad` 속성을 `True`로 설정하면, 해당 텐서에서 이루어진 모든 연산을 추적(track)하기 시작
# - 계산이 완료된 후 `.backward()`를 호출하여 모든 변화도(gradient)를 자동으로 계산할 수 있으며 이 Tensor의 변화도는 `.grad` 속성에 누적됨
# - Tensor가 기록을 추적하는 것을 중단하게 하려면, `.detach()`를 호출하여 연산기록으로부터 분리하여 연산이 추적되는 것을 방지할 수 있음
# - 기록을 추적하는 것(과 메모리를 사용하는 것)을 방지하기 위해서 코드 블럭을 `with torch.no_grad():`로 감쌀 수 있음
# - 이는 변화도(gradient)는 필요 없지만 `requires_grad=True`가 설정되어 학습 가능한 매개변수를 갖는 모델을 평가(evaluate)할 때 유용
# - Autograd 구현에서 `Function` 클래스는 매우 중요한 역할을 수행
# - `Tensor`와 `Function`은 서로 연결되어 있고 모든 연산 과정을 부호화하여 순환하지 않는 그래프를 생성
# - 각 tensor는 `.grad_fn` 속성을 가지고 있는데 이는 `Tensor`를 생성한 `Function`을 참조함(단, 사용자가 만든 Tensor는 예외이며, 사용자가 만든 Tensor가 아닌 연산에 의해 생긴 텐서와 같은 경우는 모두 `Function`을 참조)
# - 도함수를 계산하기 위해서는 `Tensor`의 `.backward()`를 호출하면 됨

# %%
import torch

print(torch.__version__)
# Out:
# 1.7.0+cu101

# %%
# x의 연산 과적을 추적하기 위해 requires_grad=True로 설정
x = torch.ones(2, 2, requires_grad=True)
print(x)

# 직접 생선한 Tensor이기 때문에 grad_fn이 None인 것을 확인할 수 있음
print(x.grad_fn)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# None

# %%
# y는 연산의 결과로 생성된 것이기 때문에 grad_fn을 갖고 있는 것을 확인 가능
y = x + 2
print(y)
# Out:
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)

# %%
# 연산의 결과로 생성된 것이기 때문에 grad_fn을 갖는 것을 확인 가능
print(y.grad_fn)
# Out:
# <AddBackward0 object at 0x7f754bb2db00>

# %%
z = y * y * 3
out = z.mean()

# 각각 사용한 func에 맞게 grad_fn이 생성된 것을 확인할 수 있음
print(z)
print(out)
# Out:
# tensor([[27., 27.],
#         [27., 27.]], grad_fn=<MulBackward0>)
# tensor(27., grad_fn=<MeanBackward0>)

# %% [markdown]
# - `requires_grad_()`를 사용하면 기존 Tensor의 `requires_grad` 값을 바꿀 수 있음
# - 입력 값이 지정되지 않으면 기본 값은 `False`

# %%
a = torch.randn(2, 2)
print(a)
# Out:
# tensor([[1.4519, 0.4120],
#         [1.0282, 0.5778]])

# %%
a = ((a * 3) / (a - 1))
print(a)
print(a.requires_grad)
# Out:
# tensor([[ 1.5595,  0.0414],
#         [ 0.0841, -2.8901]])
# False

# %%
a.requires_grad_(True)
# Out:
# tensor([[ 1.5595,  0.0414],
#         [ 0.0841, -2.8901]], requires_grad=True)

# %%
print(a.requires_grad)
# Out:
# True

# %%
b = (a * a).sum()
print(b)
print(b.requires_grad)
# Out:
# tensor(10.7936, grad_fn=<SumBackward0>)
# True

# %% [markdown]
# ## 변화도(Gradient)

# %%
print(out)

# 이전에 만든 out을 사용해서 역전파 진행
# 여러번 역전파를 하기위해서는 retain_graph=True로 지정
out.backward(retain_graph=True)
# out.backward(torch.tensor(1.))을 진행하는 것과 동일
# Out:
# tensor(27., grad_fn=<MeanBackward0>)

# %%
# 역전파를 진행한 후의 x값
# d(out) / dx 
print(x.grad)
print(y.grad)
print(z.is_leaf)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])
# False

# %% [markdown]
# $$ out = \frac{1}{4} \sum_{i} z_i $$
# $$ z_i = 3(x_i + 2)^2 $$
# - `z_i`를 미분한 값에 적용하면 4.5를 동일하게 출력할 수 있음

# %% [markdown]
# out(미분결과) = 1/4 * 6 * (x + 2) = 3/2(x+2)

# %% [markdown]
# ---

# %% [markdown]
# - 일반적으로 `torch.autograd`는 벡터-야코비안 곱을 계산하는 엔진
# - `torch.autograd`를 사용하면 전체 야코비안을 직접 계산할 수는 없지만, 벡터-야코비안 곱은 `backward`에 해당 벡터를 인자로 제공하여 얻을 수 있음

# %%
x = torch.randn(3, requires_grad=True)

y = x * 2

while y.data.norm() < 1000:
  y = y * 2

print(y)
# Out:
# tensor([ -78.7119, -722.5096, 1101.1932], grad_fn=<MulBackward0>)

# %%
# scalar값이 아닌 y의 벡터-야코비안 곱을 구하는 과정
v = torch.tensor([0.1, 1.0, 0.0001], dtype=torch.float)
y.backward(v)

print(x.grad)
# Out:
# tensor([1.0240e+02, 1.0240e+03, 1.0240e-01])

# %% [markdown]
# - `with torch.no_grad()`로 코드 블록을 감싸서 `autograd`가 `.requires_grad=True`인 Tensor의 연산 기록을 추적하는 것을 멈출 수도 있음

# %%
print(x.requires_grad)
print((x ** 2).requires_grad)

with torch.no_grad():
  print((x ** 2).requires_grad)
# Out:
# True
# True
# False

# %% [markdown]
# - 또는 `.detach()`를 호출하여 내용물은 같지만 `requires_grad`가 다른 새로운 텐서를 가져올 수 있음

# %%
print(x.requires_grad)
y = x.detach()
print(y.requires_grad)
print(x.eq(y).all())
# Out:
# True
# False
# tensor(True)

# %% [markdown]
# # ANN(Artificial Neural Networks)
#
# - 신경망은 `torch.nn` 패키지를 사용하여 생성할 수 있음
# - `nn`은 모델을 정의하고 미분하기 위해서 위에서 살펴본 `autograd`를 사용
# - `nn.Module`은 계층(layer)과 `output`을 반환하는 `forward(input)` 메소드를 포함

# %% [markdown]
# ---

# %% [markdown]
# - 간단한 순전파 네트워크(feed-forward-network)
# - 입력을 받아 여러 계층에 차례로 전달한 후, 최종 출력을 제공
# - 신경망의 일반적인 학습 과정
#
#
# > - 학습 가능한 매개변수(가중치)를 갖는 신경망을 정의
# > - 데이터 셋 입력을 반복
# > - 입력을 신경망에서 전파(process)
# > - 손실(loss; 입력 값과 예측 값과의 차이)를 계산
# > - 변화도(gradient)를 신경망의 매개변수들에 역으로 전파 - 역전파 과정
# > - 신경망의 가중치를 갱신
# > > - `새로운 가중치(weight) = 가중치(weight) - 학습률(learning rate) * 변화도(gradient)`

# %%
import pandas as pd

from sklearn.datasets import load_iris

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()

        self.layer0 = nn.Linear(4, 128)
        self.layer1 = nn.Linear(128, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 16)
        self.layer4 = nn.Linear(16, 3)

        self.bn0 = nn.BatchNorm1d(128)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(32)

        self.act = nn.ReLU()

    def forward(self, x):
      x = self.act(self.bn0(self.layer0(x)))
      x = self.act(self.bn1(self.layer1(x)))
      x = self.act(self.bn2(self.layer2(x)))
      x = self.act(self.layer3(x))
      x = self.layer4(x)

      return x

# %% [markdown]
# ## 손실 함수(Loss Function)
#
# - 손실 함수는 (output, target)을 한 쌍으로 입력 받아, 출력이 정답으로부터 얼마나 떨어져있는지 추정하는 값을 계산

# %% [markdown]
# - `forward`함수만 정의하고 나면 `backward`함수는 `autograd`를 사용하여 자동으로 정의됨
# - 모델의 학습 가능한 매개 변수는 `net.parameters()`에 의해 변환됨

# %%
# 랜덤 값 생성
criterion = nn.CrossEntropyLoss()

ex_X, ex_y = torch.randn([4, 4]), torch.tensor([1, 0, 2, 0])

net = Net()
output = net(ex_X)
loss = criterion(output, ex_y)
print('loss: ', loss.item())
  
net.zero_grad()

print('layer0.bias.grad before backward')
print(net.layer4.bias.grad)

print(net.layer4.bias.is_leaf)

loss.backward()

print('layer0.bias.grad after backward')
print(net.layer4.bias.grad)

"""
이 부분에서 .retain_grad() 를 사용하지 않아도 되는 이유는 weight와 bias의 파라미터가 leaf 노드이기 때문이라고 합니다.
설명이 포함된 링크들을 아래에 첨부해두니 읽어보시면 좋을 것 같습니다 :)

어떤 경우가 leaf 노드 인지 - https://discuss.pytorch.org/t/leaf-variable-was-used-in-an-inplace-operation/308/20
왜 leaf 노드인 경우에는 retain_grad()를 하지 않아도 grad 값이 나오는지 - https://discuss.pytorch.org/t/what-is-the-purpose-of-is-leaf/87000/7
"""
# Out:
# loss:  1.175143837928772
# layer0.bias.grad before backward
# None
# True
# layer0.bias.grad after backward
# tensor([-0.1852,  0.1133,  0.0718])

# %%
params = list(net.parameters())
print(len(params))
print(params[0].size())  # layer0의 weight
# Out:
# 16
# torch.Size([128, 4])

# %% [markdown]
# ## 가중치 갱신
# - 가장 단순한 갱신 규칙은 확률적 경사하강법(SGD; Stochastic Gradient Descent)
# - `새로운 가중치(weight) = 가중치(weight) - 학습률(learning rate) * 변화도(gradient)`

# %%
# torch.optim 패키지에 다양한 갱신 규칙이 규현되어 있음

import torch.optim as optim

optimizer = optim.SGD(net.parameters(), lr=0.001)

optimizer.zero_grad()
output = net(ex_X)
loss = criterion(output, ex_y)
loss.backward()
optimizer.step()  # 업데이트 진행

# %% [markdown]
# ## MLP 모델

# %%
dataset = load_iris()

data = dataset.data
label = dataset.target

print(dataset.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
print('shape of data: ', data.shape)
print('shape of label: ',label.shape)
# Out:
# shape of data:  (150, 4)
# shape of label:  (150,)

# %%
# 훈련과 테스트 데이터로 나누기
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.25)
print(len(X_train))
print(len(X_test))
# Out:
# 112
# 38

# %%
# DataLoader 생성
X_train = torch.from_numpy(X_train).float()
y_train = torch.from_numpy(y_train).long()

X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).long()

train_set = TensorDataset(X_train, y_train)

train_loader = DataLoader(train_set, batch_size=4, shuffle=True)

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()

        self.layer0 = nn.Linear(4, 128)
        self.layer1 = nn.Linear(128, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 16)
        self.layer4 = nn.Linear(16, 3)

        self.bn0 = nn.BatchNorm1d(128)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(32)

        self.act = nn.ReLU()

    def forward(self, x):
      x = self.act(self.bn0(self.layer0(x)))
      x = self.act(self.bn1(self.layer1(x)))
      x = self.act(self.bn2(self.layer2(x)))
      x = self.act(self.layer3(x))
      x = self.layer4(x)

      return x
      # return nn.Softmax(x)

# %%
net = Net()
print(net)
# Out:
# Net(
#   (layer0): Linear(in_features=4, out_features=128, bias=True)
#   (layer1): Linear(in_features=128, out_features=64, bias=True)
#   (layer2): Linear(in_features=64, out_features=32, bias=True)
#   (layer3): Linear(in_features=32, out_features=16, bias=True)
#   (layer4): Linear(in_features=16, out_features=3, bias=True)
#   (bn0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act): ReLU()
# )

# %%
optimizer = torch.optim.SGD(net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
epochs = 200

# %%
losses = list()
accuracies = list()

for epoch in range(epochs):
  epoch_loss = 0  
  epoch_accuracy = 0
  for X, y in train_loader:
  
    optimizer.zero_grad()
    
    output = net(X)

    loss = criterion(output, y)
    loss.backward()
    
    optimizer.step()
    # output = [0.11, 0.5, 0.8]  --> 예측 클래스 값
    _, predicted = torch.max(output, dim=1)
    accuracy = (predicted == y).sum().item()
    epoch_loss += loss.item()
    epoch_accuracy += accuracy
  

  epoch_loss /= len(train_loader)
  epoch_accuracy /= len(X_train)
  print("epoch :{}, \tloss :{}, \taccuracy :{}".format(str(epoch+1).zfill(3),round(epoch_loss,4), round(epoch_accuracy,4)))
  
  losses.append(epoch_loss)
  accuracies.append(epoch_accuracy)
# Out:
# epoch :001, 	loss :1.0645, 	accuracy :0.4911
# epoch :002, 	loss :0.9017, 	accuracy :0.6429
# epoch :003, 	loss :0.8214, 	accuracy :0.7232
# epoch :004, 	loss :0.7684, 	accuracy :0.6875
# epoch :005, 	loss :0.6619, 	accuracy :0.7679
# epoch :006, 	loss :0.6424, 	accuracy :0.7679
# epoch :007, 	loss :0.5079, 	accuracy :0.7946
# epoch :008, 	loss :0.5343, 	accuracy :0.8125
# epoch :009, 	loss :0.5635, 	accuracy :0.7946
# epoch :010, 	loss :0.562, 	accuracy :0.7857
# epoch :011, 	loss :0.6033, 	accuracy :0.7589
# epoch :012, 	loss :0.5028, 	accuracy :0.7679
# epoch :013, 	loss :0.5365, 	accuracy :0.7768
# epoch :014, 	loss :0.5166, 	accuracy :0.7857
# epoch :015, 	loss :0.509, 	accuracy :0.7768
# epoch :016, 	loss :0.4329, 	accuracy :0.8125
# epoch :017, 	loss :0.3815, 	accuracy :0.8571
# epoch :018, 	loss :0.4462, 	accuracy :0.8036
# epoch :019, 	loss :0.4145, 	accuracy :0.8214
# epoch :020, 	loss :0.4839, 	accuracy :0.7679
# epoch :021, 	loss :0.3861, 	accuracy :0.8482
# epoch :022, 	loss :0.4071, 	accuracy :0.8125
# epoch :023, 	loss :0.4957, 	accuracy :0.7857
# epoch :024, 	loss :0.2964, 	accuracy :0.8929
# epoch :025, 	loss :0.3479, 	accuracy :0.875
# epoch :026, 	loss :0.4259, 	accuracy :0.8304
# epoch :027, 	loss :0.4003, 	accuracy :0.8482
# epoch :028, 	loss :0.3535, 	accuracy :0.8661
# epoch :029, 	loss :0.348, 	accuracy :0.8393
# epoch :030, 	loss :0.397, 	accuracy :0.8571
# epoch :031, 	loss :0.3546, 	accuracy :0.8304
# epoch :032, 	loss :0.3673, 	accuracy :0.8661
# epoch :033, 	loss :0.3263, 	accuracy :0.875
# epoch :034, 	loss :0.3763, 	accuracy :0.8571
# epoch :035, 	loss :0.3614, 	accuracy :0.8482
# epoch :036, 	loss :0.3227, 	accuracy :0.8929
# epoch :037, 	loss :0.4581, 	accuracy :0.8214
# epoch :038, 	loss :0.2851, 	accuracy :0.9107
# epoch :039, 	loss :0.4714, 	accuracy :0.7946
# epoch :040, 	loss :0.3712, 	accuracy :0.875
# epoch :041, 	loss :0.541, 	accuracy :0.7946
# epoch :042, 	loss :0.2425, 	accuracy :0.9196
# epoch :043, 	loss :0.356, 	accuracy :0.8393
# epoch :044, 	loss :0.3299, 	accuracy :0.8482
# epoch :045, 	loss :0.382, 	accuracy :0.8036
# epoch :046, 	loss :0.2552, 	accuracy :0.8929
# epoch :047, 	loss :0.2815, 	accuracy :0.875
# epoch :048, 	loss :0.3809, 	accuracy :0.8929
# epoch :049, 	loss :0.3101, 	accuracy :0.8929
# epoch :050, 	loss :0.3698, 	accuracy :0.8482
# epoch :051, 	loss :0.3454, 	accuracy :0.8393
# epoch :052, 	loss :0.3618, 	accuracy :0.8304
# epoch :053, 	loss :0.3055, 	accuracy :0.8839
# epoch :054, 	loss :0.4658, 	accuracy :0.8036
# epoch :055, 	loss :0.2971, 	accuracy :0.8661
# epoch :056, 	loss :0.3051, 	accuracy :0.8661
# epoch :057, 	loss :0.4235, 	accuracy :0.8214
# epoch :058, 	loss :0.3281, 	accuracy :0.8571
# epoch :059, 	loss :0.2619, 	accuracy :0.9107
# epoch :060, 	loss :0.2952, 	accuracy :0.8839
# epoch :061, 	loss :0.5975, 	accuracy :0.7411
# epoch :062, 	loss :0.3046, 	accuracy :0.8929
# epoch :063, 	loss :0.3419, 	accuracy :0.875
# epoch :064, 	loss :0.3529, 	accuracy :0.8393
# epoch :065, 	loss :0.569, 	accuracy :0.8571
# epoch :066, 	loss :0.2561, 	accuracy :0.9018
# epoch :067, 	loss :0.269, 	accuracy :0.8929
# epoch :068, 	loss :0.4562, 	accuracy :0.8482
# epoch :069, 	loss :0.4376, 	accuracy :0.8661
# epoch :070, 	loss :0.5613, 	accuracy :0.7857
# epoch :071, 	loss :0.4528, 	accuracy :0.8036
# epoch :072, 	loss :0.3753, 	accuracy :0.8393
# epoch :073, 	loss :0.2946, 	accuracy :0.8393
# epoch :074, 	loss :0.2882, 	accuracy :0.9018
# epoch :075, 	loss :0.3206, 	accuracy :0.8839
# epoch :076, 	loss :0.3027, 	accuracy :0.8393
# epoch :077, 	loss :0.3108, 	accuracy :0.8661
# epoch :078, 	loss :0.3296, 	accuracy :0.8661
# epoch :079, 	loss :0.3805, 	accuracy :0.8661
# epoch :080, 	loss :0.2812, 	accuracy :0.8929
# epoch :081, 	loss :0.277, 	accuracy :0.8929
# epoch :082, 	loss :0.3197, 	accuracy :0.8929
# epoch :083, 	loss :0.4055, 	accuracy :0.8125
# epoch :084, 	loss :0.5752, 	accuracy :0.7768
# epoch :085, 	loss :0.537, 	accuracy :0.7946
# epoch :086, 	loss :0.3248, 	accuracy :0.8661
# epoch :087, 	loss :0.2793, 	accuracy :0.8571
# epoch :088, 	loss :0.3768, 	accuracy :0.8036
# epoch :089, 	loss :0.2744, 	accuracy :0.8482
# epoch :090, 	loss :0.3363, 	accuracy :0.8214
# epoch :091, 	loss :0.3038, 	accuracy :0.8304
# epoch :092, 	loss :0.3174, 	accuracy :0.8929
# epoch :093, 	loss :0.2791, 	accuracy :0.875
# epoch :094, 	loss :0.3668, 	accuracy :0.8393
# epoch :095, 	loss :0.3036, 	accuracy :0.8571
# epoch :096, 	loss :0.2278, 	accuracy :0.9018
# epoch :097, 	loss :0.2906, 	accuracy :0.8393
# epoch :098, 	loss :0.4918, 	accuracy :0.8125
# epoch :099, 	loss :0.4308, 	accuracy :0.8482
# epoch :100, 	loss :0.3921, 	accuracy :0.8571
# epoch :101, 	loss :0.3382, 	accuracy :0.8125
# epoch :102, 	loss :0.4055, 	accuracy :0.8393
# epoch :103, 	loss :0.5036, 	accuracy :0.8125
# epoch :104, 	loss :0.3406, 	accuracy :0.8482
# epoch :105, 	loss :0.3159, 	accuracy :0.8304
# epoch :106, 	loss :0.4061, 	accuracy :0.7768
# epoch :107, 	loss :0.3484, 	accuracy :0.8393
# epoch :108, 	loss :0.4591, 	accuracy :0.8304
# epoch :109, 	loss :0.2871, 	accuracy :0.8839
# epoch :110, 	loss :0.3617, 	accuracy :0.8304
# epoch :111, 	loss :0.2255, 	accuracy :0.9107
# epoch :112, 	loss :0.3356, 	accuracy :0.8571
# epoch :113, 	loss :0.3835, 	accuracy :0.8482
# epoch :114, 	loss :0.2797, 	accuracy :0.8661
# epoch :115, 	loss :0.3845, 	accuracy :0.8661
# epoch :116, 	loss :0.3114, 	accuracy :0.8839
# epoch :117, 	loss :0.273, 	accuracy :0.8839
# epoch :118, 	loss :0.3553, 	accuracy :0.8571
# epoch :119, 	loss :0.3477, 	accuracy :0.8571
# epoch :120, 	loss :0.4688, 	accuracy :0.8482
# epoch :121, 	loss :0.3492, 	accuracy :0.8661
# epoch :122, 	loss :0.2471, 	accuracy :0.8929
# epoch :123, 	loss :0.3508, 	accuracy :0.8125
# epoch :124, 	loss :0.307, 	accuracy :0.8482
# epoch :125, 	loss :0.284, 	accuracy :0.8482
# epoch :126, 	loss :0.3543, 	accuracy :0.8482
# epoch :127, 	loss :0.2838, 	accuracy :0.8839
# epoch :128, 	loss :0.269, 	accuracy :0.8839
# epoch :129, 	loss :0.3262, 	accuracy :0.8482
# epoch :130, 	loss :0.2665, 	accuracy :0.875
# epoch :131, 	loss :0.2837, 	accuracy :0.875
# epoch :132, 	loss :0.4162, 	accuracy :0.8214
# epoch :133, 	loss :0.4444, 	accuracy :0.7946
# epoch :134, 	loss :0.3011, 	accuracy :0.8839
# epoch :135, 	loss :0.1854, 	accuracy :0.9554
# epoch :136, 	loss :0.2467, 	accuracy :0.9018
# epoch :137, 	loss :0.2842, 	accuracy :0.8571
# epoch :138, 	loss :0.3783, 	accuracy :0.8393
# epoch :139, 	loss :0.2942, 	accuracy :0.8571
# epoch :140, 	loss :0.2632, 	accuracy :0.8839
# epoch :141, 	loss :0.2834, 	accuracy :0.8839
# epoch :142, 	loss :0.3556, 	accuracy :0.8929
# epoch :143, 	loss :0.4248, 	accuracy :0.8571
# epoch :144, 	loss :0.4802, 	accuracy :0.8214
# epoch :145, 	loss :0.2306, 	accuracy :0.9107
# epoch :146, 	loss :0.2907, 	accuracy :0.8661
# epoch :147, 	loss :0.2926, 	accuracy :0.8571
# epoch :148, 	loss :0.2959, 	accuracy :0.8661
# epoch :149, 	loss :0.3726, 	accuracy :0.8214
# epoch :150, 	loss :0.4042, 	accuracy :0.8393
# epoch :151, 	loss :0.4571, 	accuracy :0.8125
# epoch :152, 	loss :0.4052, 	accuracy :0.8571
# epoch :153, 	loss :0.375, 	accuracy :0.8571
# epoch :154, 	loss :0.3089, 	accuracy :0.875
# epoch :155, 	loss :0.2325, 	accuracy :0.9196
# epoch :156, 	loss :0.4789, 	accuracy :0.7857
# epoch :157, 	loss :0.4623, 	accuracy :0.7946
# epoch :158, 	loss :0.2862, 	accuracy :0.9107
# epoch :159, 	loss :0.2173, 	accuracy :0.9196
# epoch :160, 	loss :0.2839, 	accuracy :0.8571
# epoch :161, 	loss :0.4497, 	accuracy :0.7857
# epoch :162, 	loss :0.329, 	accuracy :0.8304
# epoch :163, 	loss :0.378, 	accuracy :0.875
# epoch :164, 	loss :0.2604, 	accuracy :0.9107
# epoch :165, 	loss :0.309, 	accuracy :0.8839
# epoch :166, 	loss :0.3241, 	accuracy :0.8929
# epoch :167, 	loss :0.2879, 	accuracy :0.8661
# epoch :168, 	loss :0.3484, 	accuracy :0.8571
# epoch :169, 	loss :0.209, 	accuracy :0.9286
# epoch :170, 	loss :0.24, 	accuracy :0.9018
# epoch :171, 	loss :0.295, 	accuracy :0.8661
# epoch :172, 	loss :0.4039, 	accuracy :0.8304
# epoch :173, 	loss :0.3001, 	accuracy :0.8482
# epoch :174, 	loss :0.3502, 	accuracy :0.875
# epoch :175, 	loss :0.282, 	accuracy :0.875
# epoch :176, 	loss :0.3063, 	accuracy :0.8929
# epoch :177, 	loss :0.4807, 	accuracy :0.8393
# epoch :178, 	loss :0.2224, 	accuracy :0.9286
# epoch :179, 	loss :0.2451, 	accuracy :0.9196
# epoch :180, 	loss :0.2631, 	accuracy :0.8839
# epoch :181, 	loss :0.2854, 	accuracy :0.8571
# epoch :182, 	loss :0.3137, 	accuracy :0.875
# epoch :183, 	loss :0.3894, 	accuracy :0.8571
# epoch :184, 	loss :0.2001, 	accuracy :0.9286
# epoch :185, 	loss :0.2888, 	accuracy :0.9196
# epoch :186, 	loss :0.3478, 	accuracy :0.8571
# epoch :187, 	loss :0.305, 	accuracy :0.8482
# epoch :188, 	loss :0.3483, 	accuracy :0.8482
# epoch :189, 	loss :0.3948, 	accuracy :0.8304
# epoch :190, 	loss :0.4093, 	accuracy :0.8482
# epoch :191, 	loss :0.4917, 	accuracy :0.7857
# epoch :192, 	loss :0.4023, 	accuracy :0.8393
# epoch :193, 	loss :0.2567, 	accuracy :0.8929
# epoch :194, 	loss :0.3027, 	accuracy :0.8661
# epoch :195, 	loss :0.2473, 	accuracy :0.8839
# epoch :196, 	loss :0.2338, 	accuracy :0.8929
# epoch :197, 	loss :0.481, 	accuracy :0.8036
# epoch :198, 	loss :0.3077, 	accuracy :0.8304
# epoch :199, 	loss :0.2223, 	accuracy :0.8929
# epoch :200, 	loss :0.3521, 	accuracy :0.8571

# %%
# Plot result

import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
plt.subplots_adjust(wspace=0.2)

plt.subplot(1,2,1)
plt.title("$loss$",fontsize = 18)
plt.plot(losses)
plt.grid()
plt.xlabel("$epochs$", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)


plt.subplot(1,2,2)
plt.title("$accuracy$", fontsize = 18)
plt.plot(accuracies)
plt.grid()
plt.xlabel("$epochs$", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

plt.show()

# %%
# Test

output = net(X_test)
print(torch.max(output, dim=1))
_, predicted = torch.max(output, dim=1)
accuracy = round((predicted == y_test).sum().item() / len(y_test),4)


print("test_set accuracy :", round(accuracy,4))
# Out:
# torch.return_types.max(
# values=tensor([2.0446, 2.3004, 3.1769, 3.1245, 2.0752, 1.8967, 2.1025, 2.2276, 2.7243,
#         3.2919, 2.1840, 1.5114, 0.8768, 1.8298, 2.2128, 2.8674, 2.6057, 2.2955,
#         0.9949, 2.3581, 1.9427, 2.2954, 2.5425, 3.2861, 1.3752, 3.7511, 0.9349,
#         0.9320, 2.8969, 1.6617, 2.5903, 2.2708, 1.7655, 3.3701, 0.7997, 2.3037,
#         3.4290, 2.5929], grad_fn=<MaxBackward0>),
# indices=tensor([2, 0, 0, 0, 1, 1, 1, 1, 0, 2, 1, 0, 2, 2, 0, 0, 2, 1, 2, 0, 0, 2, 0, 2,
#         1, 0, 1, 1, 2, 1, 2, 0, 1, 0, 1, 2, 0, 1]))
# test_set accuracy : 0.9474
