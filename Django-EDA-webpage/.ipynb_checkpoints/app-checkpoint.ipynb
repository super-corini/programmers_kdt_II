# %% [markdown]
# # World Happiness Report
# Happiness scored according to economic production, social support, etc.
# - pandas API레퍼런스 : <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html>
# - seaborn API레퍼런스 : <http://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot>
# <br>
#
# 1. 라이브러리, 데이터 불러오기
# 2. 분석의 목적과 변수 확인
# 3. 데이터 전체적으로 살펴보기
# 4. 데이터의 개별 속성 파악하기
# <br>
#
# ## 1. 라이브러리, 데이터 불러오기
# ### 라이브러리 불러오기
#
# ### 데이터 불러오기
# ```python
# data15 = pd.read_csv('./data/word_happiness_report/2015.csv')
# data16 = pd.read_csv('./data/word_happiness_report/2016.csv')
# data17 = pd.read_csv('./data/word_happiness_report/2017.csv')
# data18 = pd.read_csv('./data/word_happiness_report/2018.csv')
# data19 = pd.read_csv('./data/word_happiness_report/2019.csv')
# ```

# %%
# 라이브러리 선언
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry_convert as pc
import plotly 
plotly.offline.init_notebook_mode (connected = True)

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !python3 -m pip install plotly --user

# %%
data15 = pd.read_csv('./data/word_happiness_report/2015.csv')
data15['Year'] = 2015
data16 = pd.read_csv('./data/word_happiness_report/2016.csv')
data16['Year'] = 2016
data17 = pd.read_csv('./data/word_happiness_report/2017.csv')
data17['Year'] = 2017
data18 = pd.read_csv('./data/word_happiness_report/2018.csv')
data18['Year'] = 2018
data19 = pd.read_csv('./data/word_happiness_report/2019.csv')
data19['Year'] = 2019
# data = pd.concat([data15,data16,data17,data18,data19])
# data
# sns.heatmap(data.corr(), annot=True)
# 위와 같이 5개의 데이터를 한번에 합쳤더니 column도 다 다르고, 결측치도 많아서 엄청나게 더러워졌다 ㅠ
# 일단 각 column을 살펴보면서 정리해줘야겠다! 버릴 건 drop하고, 의미가 같지만 이름이 다른 column끼리는 통합해주고.

# %% [markdown]
# ## 2. 분석의 목적과 변수 확인
# - 행복에 기여하는 6가지 요소는 서로 어떤 상관관계를 가질까?
# - 어떤 요소들이 행복을 증진하는데 기여를 할까?
# - 전체적인 행복과 행복에 기여하는 6 가지 요소 각각에서 가장 높은 순위를 차지하는 국가 또는 지역은 어디일까?
# - 2015 년과 2016 년, 2016 년과 2017 년 보고서 사이에 국가 순위 또는 점수가 어떻게 변경 되었는가? 행복이 크게 증가하거나 감소한 나라가 있는가?
# <br>
#
# ## 3. 데이터 전체적으로 살펴보기

# %%
data15.head(5)
# Standard Error는 2015년에만 존재한다.
# Dystopia Residual도 2015년과 2016년에만 존재한다. 2017년의 Dystopia.Residual와 같다.
# Region은 2015, 2016년에만 있다.
# Country는 다른 연도의 Country or region과 같은 내용을 담고 있다.
# Overall rank == Happiness Rank
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data16.head(5)
# Dystopia Residual도 2015년과 2016년에만 존재한다. 2017년의 Dystopia.Residual와 같다.
# Region은 2015, 2016년에만 있다.
# Country는 다른 연도의 Country or region과 같은 내용을 담고 있다.
# Lower Confidence Interval은 2016년에만 있다.
# Upper Confidence Interval도 2016년에만 있다.
# Overall rank == Happiness Rank
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data17.head(5)
# Country는 다른 연도의 Country or region과 같은 내용을 담고 있다.
# Whisker.high는 2017년에만 있다.
# Whisker.low도 2017년에만 있다.
# Dystopia.Residual는 2017년에만 있다. 2015,1016년의 Dystopia Residual와 같다.
# Overall rank == Happiness Rank
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# ...

# %%
data18.head(5)
# Country or region은 다른 연도의 Country와 같은 내용을 담고 있다.
# Overall rank == Happiness Rank
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
data19.head(5)
# Country or region은 다른 연도의 Country와 같은 내용을 담고 있다.
# Overall rank == Happiness Rank
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %% [markdown]
# 같은 의미이지만 다른 이름을 갖고 있는 column들의 이름을 통일해준다.

# %%
data15=data15.rename(columns={"Economy (GDP per Capita)":"GDP per capita",
                            "Health (Life Expectancy)":"Healthy life expectancy",
                            "Trust (Government Corruption)":"Perceptions of corruption"})
data16=data16.rename(columns={"Economy (GDP per Capita)":"GDP per capita",
                            "Health (Life Expectancy)":"Healthy life expectancy",
                            "Trust (Government Corruption)":"Perceptions of corruption"})
data17=data17.rename(columns={"Happiness.Score":"Happiness Score",
                            "Economy..GDP.per.Capita.":"GDP per capita",
                            "Health..Life.Expectancy.":"Healthy life expectancy",
                            "Trust..Government.Corruption.":"Perceptions of corruption",
                             "Happiness.Rank" : "Happiness Rank"})
data18=data18.rename(columns={"Country or region":"Country",
                              "Freedom to make life choices" : "Freedom",
                             "Score" : "Happiness Score",
                             "Social support" : "Family",
                             "Overall rank" : "Happiness Rank"})
data19=data19.rename(columns={"Country or region":"Country",
                              "Freedom to make life choices" : "Freedom",
                             "Score" : "Happiness Score",
                             "Social support" : "Family",
                             "Overall rank" : "Happiness Rank"})

# %% [markdown]
# 15~19년도 데이터를 병합해준다.

# %%
alldata = pd.concat([data15,data16,data17,data18,data19])
# alldata

# %% [markdown]
# 모든 연도에서 공통적으로 갖고 있지 않은 column들을 제거해준다.

# %%
# data15.drop(columns="Standard Error",inplace=True,errors="ignore", axis=1)
# data15.drop(columns="Dystopia Residual",inplace=True,errors="ignore", axis=1)
# data15.drop(columns="Region",inplace=True,errors="ignore", axis=1)

# data16.drop(columns="Lower Confidence Interval",inplace=True,errors="ignore", axis=1)
# data16.drop(columns="Upper Confidence Interval",inplace=True,errors="ignore", axis=1)
# data16.drop(columns="Dystopia Residual",inplace=True,errors="ignore", axis=1)
# data16.drop(columns="Region",inplace=True,errors="ignore", axis=1)

# data17.drop(columns="Whisker.high",inplace=True,errors="ignore", axis=1)
# data17.drop(columns="Whisker.low",inplace=True,errors="ignore", axis=1)
# data17.drop(columns="Dystopia.Residual",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Standard Error",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Dystopia Residual",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Dystopia.Residual",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Region",inplace=True,errors="ignore", axis=1)

alldata.drop(columns="Lower Confidence Interval",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Upper Confidence Interval",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Whisker.high",inplace=True,errors="ignore", axis=1)
alldata.drop(columns="Whisker.low",inplace=True,errors="ignore", axis=1)

# %%
# alldata

# %%
# Match region from df_15 to countries from our df by using merge:
df_reg = data15[['Country', 'Region']]
alldata = alldata.merge(df_reg)
# alldata

# %%
# !python3 -m pip install pycountry_convert

# %%
# import pycountry_convert as pc

def country_2_continent(country_name):
    try:
        if country_name in ['Holy See', 'Kosovo']:
            return 'Europe'
        if country_name in ['North Cyprus','East Timor','Timor-Leste','West Bank and Gaza','Palestinian Territories','Taiwan Province of China','Hong Kong S.A.R., China']:
            return 'Asia'
        if country_name in ['Congo (Brazzaville)','Congo (Kinshasa)','Somaliland region', 'Somaliland Region']:
            return 'Africa'
        if country_name in ['Trinidad & Tobago']:
            return 'South America'
        else:
            country_alpha2 = pc.country_name_to_country_alpha2(country_name)
            country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
            country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
            return country_continent_name
    
    except:
         return 'Other'

# %%
alldata['Continent'] = alldata['Country'].apply(country_2_continent)
alldata
# Out:
#          Country  Happiness Rank  Happiness Score  GDP per capita    Family  \
# 0    Switzerland               1            7.587        1.396510  1.349510
# 1    Switzerland               2            7.509        1.527330  1.145240
# 2    Switzerland               4            7.494        1.564980  1.516912
# 3    Switzerland               5            7.487        1.420000  1.549000
# 4    Switzerland               6            7.480        1.452000  1.526000
# ..           ...             ...              ...             ...       ...
# 752         Togo             158            2.839        0.208680  0.139950
# 753         Togo             155            3.303        0.281230  0.000000
# 754         Togo             150            3.495        0.305445  0.431883
# 755         Togo             139            3.999        0.259000  0.474000
# 756         Togo             139            4.085        0.275000  0.572000
#
# ...

# %% [markdown]
# 데이터가 결측치를 갖는지 확인해보자.

# %%
alldata.iloc[:, :].isnull().sum()
# Out:
# Country                      0
# Happiness Rank               0
# Happiness Score              0
# GDP per capita               0
# Family                       0
# Healthy life expectancy      0
# Freedom                      0
# Perceptions of corruption    1
# Generosity                   0
# Year                         0
# Region                       0
# Continent                    0
# dtype: int64

# %% [markdown]
# Perceptions of corruption에 결측치가 하나 존재하지만, 미미한 정도의 수준이므로 넘어가도록 하자.
# <br>
# <br>
#
# - 행복에 기여하는 6가지 요소는 서로 어떤 상관관계를 가질까?
# - 어떤 요소들이 행복을 증진하는데 기여를 할까?
# - 전체적인 행복과 행복에 기여하는 6 가지 요소 각각에서 가장 높은 순위를 차지하는 국가 또는 지역은 어디일까?
# - 2015 년과 2016 년, 2016 년과 2017 년 보고서 사이에 국가 순위 또는 점수가 어떻게 변경 되었는가? 행복이 크게 증가하거나 감소한 나라가 있는가?
#
# 각 column에 대한 설명은 다음과 같다.
# - Country or Region
#     - 연도별 국가 순위를 보고 행복이 크게 증가하거나 감소한 나라가 있는지 살펴볼 수 있겠다.
# - Happiness Rank : Rank of the country based on the Happiness Score.
#     - Happiness Score와 같이 취급해도 될 것이다.
# - Happiness Score : A metric measured by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest."
#     - Happiness Rank와 같이 취급해도 될 것이다.
# - Economy : real GDP per capita
#     - 경제적으로 얼마나 부유한지를 의미한다.
# - Family : social support
#     - 가족 수를 의미한다.
# - Health : healthy life expectancy
#     - 건강한 삶에 대한 기대 정도.
# - Freedom : freedom to make life choices
#     - 인생에 있어 선택에 대한 자유.
# - Trust : perceptions of corruption
#     - 국가 부패에 대한 인식
# - Generosity : perceptions of generosity
#     - 관대함에 대한 인식. 행복할수록 관대한 성격의 사람이 많은 것일까? 각 국가별 문화에도 영향을 줄 것 같다.
# - Dystopia : each country is compared against a hypothetical nation that represents the lowest national averages for each key variable and is, along with residual error, used as a regression benchmark
#     - 이 부분은 어떤 연도에는 측정되지 않아 삭제했다.

# %% [markdown]
# **상관계수에 대하여**
# - -1에 가까운 값이 얻어지면 : 누가 봐도 매우 강력한 음(-)의 상관. 오히려 너무 확고하기 때문에 사회과학 데이터일 경우 데이터를 조작한 게 아닌가 의심할 정도이다. 물론 이건 사회과학 얘기고 순수학문에 가까운 분야일수록 요구되는 상관관계는 높은 편.
# - -0.5 정도의 값이 얻어지면 : 강력한 음(-)의 상관. 연구자는 변인 x 가 증가하면 변인 y 가 감소한다고 자신 있게 말할 수 있다.
# - -0.2 정도의 값이 얻어지면 : 음(-)의 상관이긴 한데 너무 약해서 모호하다. 상관관계가 없다고는 할 수 없지만 좀 더 의심해 봐야 한다.
# - 0 정도의 값이 얻어지면 : 대부분의 경우, 상관관계가 있을거라고 간주되지 않는다. 다른 후속 연구들을 통해 뒤집어질지는 모르지만 일단은 회의적이다. 하지만 무조건적으로 그런건 아니라 2차 방정식 그래프와 비슷한 모양이 될 경우 상관관계는 있으나 상관계수는 0에 가깝게 나온다.
# - 0.2 정도의 값이 얻어지면 : 너무 약해서 의심스러운 양(+)의 상관. 이것만으로는 상관관계에 대해 아주 장담할 수는 없다. 하지만 사회과학에선 매우 큰 상관관계가 있는 것으로 간주한다.
# - 0.5 정도의 값이 얻어지면 : 강력한 양(+)의 상관. 변인 x 가 증가하면 변인 y 가 증가한다는 주장은 이제 통계적으로 지지받고 있다.
# - 1에 가까운 값이 얻어지면 : 이상할 정도로 강력한 양(+)의 상관. 위와 마찬가지로, 이렇게까지 확고한 상관관계는 오히려 쉽게 찾아보기 어렵다.
# <br>
#
# 일반적으로
#
# r이 -1.0과 -0.7 사이이면, 강한 음적 선형관계,
# r이 -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계,
# r이 -0.3과 -0.1 사이이면, 약한 음적 선형관계,
# r이 -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계,
# r이 +0.1과 +0.3 사이이면, 약한 양적 선형관계,
# r이 +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계,
# r이 +0.7과 +1.0 사이이면, 강한 양적 선형관계
# 로 해석한다.
#
# **상관계수 확인해보기**

# %%
sns.heatmap(alldata.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
alldata.corr().iloc[:, :]
# Out:
#                            Happiness Rank  Happiness Score  GDP per capita  \
# Happiness Rank                   1.000000        -0.992205       -0.802026
# Happiness Score                 -0.992205         1.000000        0.797339
# GDP per capita                  -0.802026         0.797339        1.000000
# Family                          -0.646295         0.650595        0.575385
# Healthy life expectancy         -0.748683         0.747745        0.779341
# Freedom                         -0.538112         0.550108        0.353443
# Perceptions of corruption       -0.387597         0.412705        0.341236
# Generosity                      -0.119463         0.139592       -0.005723
# Year                            -0.014137         0.014665        0.025971
#
#                              Family  Healthy life expectancy   Freedom  \
# Happiness Rank            -0.646295                -0.748683 -0.538112
# Happiness Score            0.650595                 0.747745  0.550108
# ...

# %% [markdown]
# 이제 깔끔하게 2015~20019년도를 합쳐서 column간의 상관관계를 파악할 수 있다.
# -1, 1에 가까운 이상할 정도로 강력한 상관관계를 제외하고, 어떤 요소들이 행복에 기여하는지 알아보자. Happiness Score가 높을수록 Happiness Rank는 낮아진다. Happiness Score와 Rank는 같은 의미를 갖는 column이기 때문에, 여기서는 "행복"의 기준을 Happiness Score을 기준으로 하겠다.
# <br>
# <br>
#
# **상관계수에 따른 가설 세우기**
# - Happiness Score : 행복 점수
#     - GDP per capita
#         - 0.79의 상관관계를 갖는다.
#         - GDP per capita가 높을수록, 즉 경제적으로 잘 살수록 행복지수가 높을 것이다.
#     - Family
#         - 0.65의 상관관계를 갖는다.
#         - 가족이 많을수록 행복지수가 높을 것이다.
#     - Healthy life expenctancy
#         - 0.74의 상관관계를 갖는다.
#         - 건강한 삶에 대한 기대 정도가 높을수록 행복지수가 높을 것이다.
#     - Freedom
#         - 0.55의 상관관계를 갖는다.
#         - 자유로울수록 행복지수가 높을 것이다.
#
# Happiness Score외의 요소들이 서로 갖는 상관관계에 대해 알아보자.
# - GDP per capita
#     - Family
#         - 0.59의 상관관계를 갖는다.
#         - GDP per capita가 높을수록, 즉 경제적으로 잘 살수록 가족이 많을 것이다.
#     - Healthy life expectancy
#         - 0.78의 상관관계를 갖는다.
#         - GDP per capita가 높을수록, 즉 경제적으로 잘 살수록 건강한 삶에 대한 기대 정도가 높을 것이다.
# - Freedom
#     - Family
#         - 0.42의 상관관계를 갖는다.
#         - 인생에 있어 선택에 대한 자유를 많이 느낄수록 가족이 많을 것이다.
#     - Perception of corruption
#         - 0.46의 상관관계를 갖는다.
#         - 인생에 있어 선택에 대한 자유를 많이 느낄수록 국가부패인식이 높을 것이다.
# - Healthy life expectanacy
#     - Family
#         - 0.57의 상관관계를 갖는다.
#         - 건강한 삶에 대한 기대 정도가 높을수록 가족이 많을 것이다.

# %% [markdown]
# # 4. 데이터의 개별 속성 파악하기
# **분석 목적 검토**
# - 행복에 기여하는 6가지 요소는 서로 어떤 상관관계를 가질까?
# - 어떤 요소들이 행복을 증진하는데 기여를 할까?

# %% [markdown]
# ### 1.1 Happiness Score & GDP per capita : 0.79
# GDP per capita가 높을수록, 즉 경제적으로 잘 살수록 행복지수가 높아짐을 알 수 있다.

# %%
sns.regplot(alldata['GDP per capita'],alldata['Happiness Score'], color="green")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
fig = px.scatter(alldata
                 , x ="GDP per capita"
                 , y ="Happiness Score"
                 , animation_frame ="Year"
                 , animation_group ="Country"
                 , size ="GDP per capita"
                 , color ="Continent"
                 , hover_name ="Country"
                 #, facet_col ="Continent"
                 , size_max = 10
                ) 


fig.update_layout(title_text='Happines vs GDP per Capita (sized by GDP per Capita)')
fig.update_yaxes(range=[2,8])
fig.update_xaxes(range=[-0.01,round((max(alldata['GDP per capita']))+0.1,2)])

fig.show()
# Out:
# <div>                            <div id="eb1de27e-8f2c-4685-825a-3034db0983ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb1de27e-8f2c-4685-825a-3034db0983ce")) {                    Plotly.newPlot(                        "eb1de27e-8f2c-4685-825a-3034db0983ce",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Continent=Europe<br>Year=2015<br>GDP per capita=%{marker.size}<br>Happiness Score=%{y}<extra></extra>", "hovertext": ["Switzerland", "Iceland", "Denmark", "Norway", "Finland", "Netherlands", "Sweden", "Austria", "Luxembourg", "Ireland", "Belgium", "United Kingdom", "Germany", "France", "Czech Republic", "Spain", "Malta", "Slovakia", "Italy", "Moldova", "Slovenia", "Lithuania", "Belarus", "Poland", "Croatia", "Russia",
# ...

# %% [markdown]
# ### 1.2 Happiness Score & Family : 0.65
# 가족이 많을수록, 행복지수가 높아짐을 알 수 있다.

# %%
sns.regplot(alldata['Family'], alldata['Happiness Score'], color="green")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
fig = px.scatter(alldata
                 , x ="Family"
                 , y ="Happiness Score"
                 , animation_frame ="Year"
                 , animation_group ="Country"
                 , size ="GDP per capita"
                 , color ="Continent"
                 , hover_name ="Country"
                 #, facet_col ="Continent"
                 , size_max = 10
                ) 


fig.update_layout(title_text='Happines vs Family (sized by Family)')
fig.update_yaxes(range=[2,8])
fig.update_xaxes(range=[-0.01,round((max(alldata['Family']))+0.1,2)])

fig.show()
# fig.write_html("./test.html")
# fig.write_json("./test.json")
# Out:
# <div>                            <div id="7d8d814c-da1d-42f2-9162-842759673e81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d8d814c-da1d-42f2-9162-842759673e81")) {                    Plotly.newPlot(                        "7d8d814c-da1d-42f2-9162-842759673e81",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Continent=Europe<br>Year=2015<br>Family=%{x}<br>Happiness Score=%{y}<br>GDP per capita=%{marker.size}<extra></extra>", "hovertext": ["Switzerland", "Iceland", "Denmark", "Norway", "Finland", "Netherlands", "Sweden", "Austria", "Luxembourg", "Ireland", "Belgium", "United Kingdom", "Germany", "France", "Czech Republic", "Spain", "Malta", "Slovakia", "Italy", "Moldova", "Slovenia", "Lithuania", "Belarus", "Poland", "Croa
# ...

# %% [markdown]
# ### 1.3 Happiness Score & Healthy life expectancy : 0.74
# 건강한 삶에 대한 기대 정도가 높을수록 행복지수가 높아짐을 알 수 있다.

# %%
sns.regplot(alldata['Healthy life expectancy'], alldata['Happiness Score'], color="green")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
fig = px.scatter(alldata
                 , x ="Healthy life expectancy"
                 , y ="Happiness Score"
                 , animation_frame ="Year"
                 , animation_group ="Country"
                 , size ="GDP per capita"
                 , color ="Continent"
                 , hover_name ="Country"
                 #, facet_col ="Continent"
                 , size_max = 10
                ) 


fig.update_layout(title_text='Happines vs Healthy life expectancy (sized by Healthy life expectancy)')
fig.update_yaxes(range=[2,8])
fig.update_xaxes(range=[-0.01,round((max(alldata['Healthy life expectancy']))+0.1,2)])

fig.show()
# Out:
# <div>                            <div id="b097a6c5-65ea-48e8-9fa6-785d41c4e581" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b097a6c5-65ea-48e8-9fa6-785d41c4e581")) {                    Plotly.newPlot(                        "b097a6c5-65ea-48e8-9fa6-785d41c4e581",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Continent=Europe<br>Year=2015<br>Healthy life expectancy=%{x}<br>Happiness Score=%{y}<br>GDP per capita=%{marker.size}<extra></extra>", "hovertext": ["Switzerland", "Iceland", "Denmark", "Norway", "Finland", "Netherlands", "Sweden", "Austria", "Luxembourg", "Ireland", "Belgium", "United Kingdom", "Germany", "France", "Czech Republic", "Spain", "Malta", "Slovakia", "Italy", "Moldova", "Slovenia", "Lithuania", "Belarus"
# ...

# %% [markdown]
# ### 1.4 Happiness Score & Freedom : 0.55
# 인생에 있어 선택의 자유를 많이 느낄수록 행복지수가 높아짐을 알 수 있다.

# %%
sns.regplot(alldata['Freedom'],alldata['Happiness Score'], color="green")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
fig = px.scatter(alldata
                 , x ="Freedom"
                 , y ="Happiness Score"
                 , animation_frame ="Year"
                 , animation_group ="Country"
                 , size ="GDP per capita"
                 , color ="Continent"
                 , hover_name ="Country"
                 #, facet_col ="Continent"
                 , size_max = 10
                ) 


fig.update_layout(title_text='Happines vs Freedom (sized by Freedom)')
fig.update_yaxes(range=[2,8])
fig.update_xaxes(range=[-0.01,round((max(alldata['Freedom']))+0.1,2)])

fig.show()
# Out:
# <div>                            <div id="a46f6077-b040-41be-a0cd-d241b32b4a25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a46f6077-b040-41be-a0cd-d241b32b4a25")) {                    Plotly.newPlot(                        "a46f6077-b040-41be-a0cd-d241b32b4a25",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Continent=Europe<br>Year=2015<br>Freedom=%{x}<br>Happiness Score=%{y}<br>GDP per capita=%{marker.size}<extra></extra>", "hovertext": ["Switzerland", "Iceland", "Denmark", "Norway", "Finland", "Netherlands", "Sweden", "Austria", "Luxembourg", "Ireland", "Belgium", "United Kingdom", "Germany", "France", "Czech Republic", "Spain", "Malta", "Slovakia", "Italy", "Moldova", "Slovenia", "Lithuania", "Belarus", "Poland", "Cro
# ...

# %% [markdown]
# ### 2.1 GDP per capita & Family : 0.59
# 1인당 GDP 지수가 높을수록, 즉 경제적으로 부유할수록 가족이 많음을 알 수 있다.

# %%
sns.jointplot(alldata['GDP per capita'],alldata['Family'],kind="hex")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### 2.2 GDP per capita & Healthy life expectancy : 0.78
# 1인당 GDP 지수가 높을수록, 즉 경제적으로 부유할수록 건강한 삶에 대한 기대 정도가 높음을 알 수 있다.

# %%
sns.jointplot(alldata['GDP per capita'],alldata['Healthy life expectancy'],kind="hex")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### 3.1 Freedom & Family : 0.42
# 인생에 있어 선택에 대한 자유를 많이 느낄수록 가족이 많음을 알 수 있다.

# %%
plt.xlabel('Freedom')
plt.ylabel('Family')
plt.hist(x=alldata['Freedom'], weights=alldata['Family'], bins=np.arange(0, 1, 0.1))
plt.xticks(np.arange(0, 1, 0.1)) # Extra : xticks를 올바르게 처리해봅시다.
plt.show()

# 가족이 많을수록 자유를 느끼는 사람들이 많음을 알 수 있다.

# %% [markdown]
# ### 3.2 Freedom & Perception of corruption : 0.46
# 인생에 있어 선택에 대한 자유를 많이 느낄수록 국가 부패에 대한 인식지수가 높은 경향이 있다.
# 하지만 자유도가 일정치 이상을 넘어가면, 국가 부패에 대한 인식지수가 낮아짐을 확인할 수 있다.

# %%
plt.xlabel('Freedom')
plt.ylabel('Perception of corruption')
plt.hist(x=alldata['Freedom'], weights=alldata['Family'], bins=np.arange(0, 1, 0.1))
plt.xticks(np.arange(0, 1, 0.1)) # Extra : xticks를 올바르게 처리해봅시다.
plt.show()

# %% [markdown]
# ### 4. Healthy life expectancy & Family : 0.57

# %%
sns.displot(data=alldata, x='Family', y='Healthy life expectancy')
plt.show()

# 가족이 많을수록, 건강한 삶에 대한 기대치가 높음을 알 수 있다.

# %% [markdown]
# **분석 목적 검토**
# - 전체적인 행복과 행복에 기여하는 6 가지 요소 각각에서 가장 높은 순위를 차지하는 국가 또는 지역은 어디일까?

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="GDP per capita", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,3])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="01ca199d-2e1a-426e-8f1c-21fef21371a4" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01ca199d-2e1a-426e-8f1c-21fef21371a4")) {                    Plotly.newPlot(                        "01ca199d-2e1a-426e-8f1c-21fef21371a4",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>GDP per capita=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "Central an
# ...

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Family", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,2])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="3a41e1b4-2a29-4671-8d03-a7d989e7bcea" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a41e1b4-2a29-4671-8d03-a7d989e7bcea")) {                    Plotly.newPlot(                        "3a41e1b4-2a29-4671-8d03-a7d989e7bcea",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Family=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "Central and Easter
# ...

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Healthy life expectancy", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,1.2])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="74180843-1048-4de8-aefd-88672bb532c9" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74180843-1048-4de8-aefd-88672bb532c9")) {                    Plotly.newPlot(                        "74180843-1048-4de8-aefd-88672bb532c9",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Healthy life expectancy=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "C
# ...

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Freedom", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0, 0.8])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="aeb4232c-71fa-445f-987f-4f3dfcf41944" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb4232c-71fa-445f-987f-4f3dfcf41944")) {                    Plotly.newPlot(                        "aeb4232c-71fa-445f-987f-4f3dfcf41944",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Freedom=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "Central and Easte
# ...

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Perceptions of corruption", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,0.6])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="7794faa2-54e4-433f-b01b-6fa0ecae4545" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7794faa2-54e4-433f-b01b-6fa0ecae4545")) {                    Plotly.newPlot(                        "7794faa2-54e4-433f-b01b-6fa0ecae4545",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Perceptions of corruption=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", 
# ...

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Generosity", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,0.6])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="85852aea-8c30-49e6-87f3-5d400c6e4721" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85852aea-8c30-49e6-87f3-5d400c6e4721")) {                    Plotly.newPlot(                        "85852aea-8c30-49e6-87f3-5d400c6e4721",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Generosity=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "Central and Ea
# ...

# %% [markdown]
# **분석 목적 검토**
# 2015 년과 2016 년, 2016 년과 2017 년 보고서 사이에 국가 순위 또는 점수가 어떻게 변경 되었는가? 행복이 크게 증가하거나 감소한 나라가 있는가?

# %%
fig = px.bar(alldata, 
             x="Region", 
             y="Happiness Score", 
             color="Continent",
             animation_frame="Year", 
             animation_group="Region", 
             range_y=[0,10])
fig.update_layout(
    height=600,
    title_text='test'
)
fig.show()
# Out:
# <div>                            <div id="e8bfdc28-025b-47ec-8bea-0e2b20165193" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8bfdc28-025b-47ec-8bea-0e2b20165193")) {                    Plotly.newPlot(                        "e8bfdc28-025b-47ec-8bea-0e2b20165193",                        [{"alignmentgroup": "True", "hovertemplate": "Continent=Europe<br>Year=2015<br>Region=%{x}<br>Happiness Score=%{y}<extra></extra>", "ids": ["Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Western Europe", "Central and Eastern Europe", "Western Europe", "Western Europe", "Central a
# ...
