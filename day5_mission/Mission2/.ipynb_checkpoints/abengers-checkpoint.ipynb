# %% [markdown]
# ## 필요한 패키지 import

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### dataset 불러오기 및 확인

# %%
abengers = pd.read_csv("./charcters_stats.csv")

# %%
abengers.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
abengers.isna().sum()
# Out:
# Name            0
# Alignment       3
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# dtype: int64

# %% [markdown]
# ## Core Mission 1 : 제일 강력한 캐릭터
# * 모든 값이 합쳐진 Total을 내림차순으로 정렬해서 뽑아내었다

# %%
abengers.sort_values(by = "Total", ascending=False).head(1)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
#
#      Power  Combat  Total
# 361    100      85    581

# %% [markdown]
# ![](https://lh3.googleusercontent.com/proxy/m3d-pT053bfBBQhV3T2BAqnzfgTaASFcvQzBtpmWBzL20CrF2rdMDzZ6C2AnpFKZf_fKBoa6oAANStXiMTdQ0jm4x2Fqv9fZsVUTdAy2NfDCkLy9pd0cZ292sw2WrhIcmbPd10UzmBsJR1kirIlsoBLcn1LoU0cLXcnBBZZST4KOZzRI0nki-xlrxmCrlA)
# 근데 누구....세요?

# %% [markdown]
# ## Core Mission 2
# * 좋은 캐릭터 나쁜 캐릭터 별로 수치분포를 알아보자

# %%
abenger = abengers[['Alignment','Intelligence','Strength','Speed','Durability','Power','Combat']]
abenger.head(5)
# Out:
#   Alignment  Intelligence  Strength  Speed  Durability  Power  Combat
# 0      good            50        31     43          32     25      52
# 1      good            38       100     17          80     17      64
# 2      good            88        14     35          42     35      85
# 3      good            50        90     53          64     84      65
# 4       bad            63        80     53          90     55      95

# %%
abenger = abenger.melt("Alignment", var_name = "status", value_name = "stat")
abenger
# Out:
#      Alignment        status  stat
# 0         good  Intelligence    50
# 1         good  Intelligence    38
# 2         good  Intelligence    88
# 3         good  Intelligence    50
# 4          bad  Intelligence    63
# ...        ...           ...   ...
# 3661      good        Combat    14
# 3662      good        Combat    28
# 3663      good        Combat    28
# 3664      good        Combat    56
# 3665       bad        Combat    28
#
# [3666 rows x 3 columns]

# %% [markdown]
# ### melt를 이용한 데이터 전처리를 해주었다(진작 알았으면 좋았을텐데)
# * total의 수치가 합산이기 때문에 다른 수치들과 비교해서 많이 커서 따로 분리해서 생각해 보았다.

# %%
plt.figure(figsize = (20,10))
sns.boxplot(data = abenger, x = "Alignment", y = "stat", hue = "status")
plt.show()

# %%
sns.catplot(data = abengers, y = "Total", x = "Alignment", kind="box")
plt.show()

# %% [markdown]
# ## 다음과 같은 결과가 나왔다
# * 기본적으로 좋은캐릭터 보다 나쁜캐릭터의 모든 능력치 평균이 더 높다
# * 중립캐릭터들은 평균적으로 매우 높은 능력치를 보유하고 있다.

# %% [markdown]
# # Extra Mission

# %% [markdown]
# # Mission 1 각각 코믹스 회사에 평균을 구하여라!

# %%
coco = pd.read_csv("./marvel_characters_info.csv")

# %% [markdown]
# ### 데이터를 합칠때 기준이 되는 이름을 index기준으로 merge를 해준다
# * Name의 교집합으로 merge를 해주어서 양 리스트에 모두 없는 캐릭터들은 제외해주었다

# %%
cocoabengers = pd.merge(abengers,coco, how='inner', on="Name")
cocoabengers
# Out:
#                 Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb        good            38       100     17          80
# 1         Abe Sapien        good            88        14     35          42
# 2           Abin Sur        good            50        90     53          64
# 3        Abomination         bad            63        80     53          90
# 4            Abraxas         bad            88       100     83          99
# ..               ...         ...           ...       ...    ...         ...
# 595     Yellowjacket        good            88        10     12          28
# 596  Yellowjacket II        good            50        10     35          28
# 597             Ymir        good            50       100     27         100
# 598          Zatanna        good            75        10     23          28
# 599             Zoom         bad            50        10    100          28
#
# ...

# %%
ax = sns.catplot(data = cocoabengers, x = "Publisher", y = "Total", kind = "box").set_xticklabels(rotation=90)
ax.fig.set_size_inches(15,10)

# %% [markdown]
# ## Shueisha 회사의 평균이 제일 높은것을 알 수 있다.

# %%
cocoabengers[cocoabengers.Publisher == "Shueisha"]
# Out:
#                Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 246            Goku        good            56       100     75          90
# 399  Naruto Uzumaki        good            50        80     32          80
#
#      Power  Combat  Total   ID Alignment_y Gender EyeColor    Race HairColor  \
# 246    100     100    521  288        good   Male        -  Saiyan         -
# 399    100     100    442  485        good   Male        -   Human         -
#
#     Publisher SkinColor  Height  Weight
# 246  Shueisha         -   175.0    62.0
# 399  Shueisha         -   168.0    54.0

# %% [markdown]
# #### 나루토...? 손오공.....?

# %% [markdown]
# # Mission 2
# * 좋은 캐릭터와 나쁜 캐릭터가 격돌한다고 한다. 격돌하는 경우 캐릭터들의 능력치의 합의 평균이 큰 팀이 이긴다고 한다. 단, 불의를 못참는 중립 캐릭터들은 중립캐릭터가 없었을 당시에 열세인 팀에 가담한다. 이러한 상황일때 결과적으로 어떤 캐릭터 진영이 승리할 것인가? 이를 보이기 위한 과정을 보여라.

# %%
sns.catplot(data = abengers, y = "Total", x = "Alignment", kind="box")
plt.show()

# %% [markdown]
# ### 기본적으로 좋은 캐릭터들의 평균 능력치 총합이 나쁜캐릭터들보다 낮은것을 알 수 있다.
# ### 여기서 중립 캐릭터들이 좋은 캐릭터쪽에 합류한다고 생각하면

# %%
def neutralisgood(row):
    if row == "neutral":
        return "good"
    else:
        return row

# %%
abengers["G&B"] = abengers["Alignment"].apply(neutralisgood)
sns.catplot(data = abengers, y = "Total", x = "G&B", kind="box")
plt.show()

# %% [markdown]
# ### 그래도 낮다.....

# %%
abengers.sort_values(by = "Total", ascending=True)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 148            Cerebra      good             1         1      1           1
# 153         Cheetah II       bad             1         1      1           1
# 154        Cheetah III       bad             1         1      1           1
# 155            Chromos       bad             1         1      1           1
# 158               Clea      good             1         1      1           1
# ..                 ...       ...           ...       ...    ...         ...
# 16               Amazo       bad            75       100    100         100
# 535     Superboy-Prime       bad            94       100    100         100
# 242        General Zod       bad            94       100     96         100
# 537           Superman      good           100       100    100         100
# 361  Martian Manhunter      good           100       100     96         100
#
#      Power  Combat  Total   G&B
# ...

# %%
abengers["Alignment"].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
abengers[abengers.Total == 5]["Alignment"].value_counts()
# Out:
# good    133
# bad      43
# Name: Alignment, dtype: int64

# %% [markdown]
# ## 데이터를 보면 total == 5 의 ~~쩌리~~캐릭터들이 많이 존재하는것을 알 수 있다.
# * 이들로 인해 충분히 많은 수의 표본집단을 추출해서 평균값을 비교 해보면 결국 모집단 좋은캐릭터와 나쁜캐릭터의 평균에 수렴하게 되기때문에 좋은캐릭터가 진다

# %% [markdown]
# ![](data:image/jpeg;base64,...)
# 역시 약해서 이기려면 비겁해야하는 영웅들

# %% [markdown]
# # Mission 3 : EDA
# * 가지고있는 데이터로 한번 EDA를 해보자 (cocoabengers)

# %% [markdown]
# ##  1. 기초작업

# %% [markdown]
# -  ### 상위데이터 5개 확인

# %%
cocoabengers.head(5)
# Out:
#           Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 0       A-Bomb        good            38       100     17          80     17
# 1   Abe Sapien        good            88        14     35          42     35
# 2     Abin Sur        good            50        90     53          64     84
# 3  Abomination         bad            63        80     53          90     55
# 4      Abraxas         bad            88       100     83          99    100
#
#    Combat  Total  ID Alignment_y Gender EyeColor               Race HairColor  \
# 0      64    316   0        good   Male   yellow              Human   No Hair
# 1      85    299   1        good   Male     blue      Icthyo Sapien   No Hair
# 2      65    406   2        good   Male     blue            Ungaran   No Hair
# 3      95    436   3         bad   Male    green  Human / Radiation   No Hair
# 4      56    526   4         bad   Male     blue      Cosmic Entity     Black
#
# ...

# %% [markdown]
# * ###  전반적인 데이터 확인

# %%
cocoabengers.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    600.000000  600.000000  600.000000  600.000000  600.000000
# mean      45.460000   29.988333   27.960000   43.008333   41.108333
# std       32.939795   32.894553   25.936324   36.858774   34.769932
# min        1.000000    1.000000    1.000000    1.000000    0.000000
# 25%        1.000000    1.000000    1.000000    1.000000    0.000000
# 50%       50.000000   11.000000   23.000000   40.000000   38.000000
# 75%       75.000000   55.000000   42.000000   80.000000   69.000000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total          ID      Height      Weight
# count  600.000000  600.000000  600.000000  600.000000  600.000000
# mean    43.840000  231.365000  362.248333  105.593333   50.283333
# std     33.207061  168.141799  215.257574  140.193334  133.887625
# min      1.000000    5.000000    0.000000  -99.000000  -99.000000
# ...

# %%
cocoabengers.isna().sum()
# Out:
# Name            0
# Alignment_x     3
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# ID              0
# Alignment_y     0
# Gender          0
# EyeColor        0
# Race            0
# HairColor       0
# Publisher       7
# SkinColor       0
# Height          0
# Weight          0
# dtype: int64

# %% [markdown]
# ### Height, Weight의 -99 는 결측치로 예상됨(marvel fandom 검색해봤는데 안나옴)

# %% [markdown]
#  *  ### 상관관계 분석

# %%
sns.heatmap(data = cocoabengers.corr())
plt.show()

# %% [markdown]
# * 각각의 능력치가 높을수록 Total 이 높은 경향을 보임(당연하지만)
# * 신기하게도 combat은 다른 능력치보다 Intelligence와 높은 상관관계를 보임
# * 그 외에 Strength 와 Durability도 높은 상관관계를 보였음

# %% [markdown]
# ## 2. 가정을 증명할 수 있을만한 자료를 제시하자

# %% [markdown]
# * ### 가정1 : 이 세상에는 대머리 = 악당 이라는 공식이 팽배하다. 이것이 사실인지 아닌지 보여줄 수 있는 자료를 한번 제시해보자

# %%
#좋음 = 1 나쁨 = 0 중립 = 0.5
def isgood(row):
    if row == "good":
        return 1
    elif row == "bad":
        return 0
    elif row == "neutral":
        return 0.5

# %%
cocoabengers.Alignment_x = cocoabengers["Alignment_x"].apply(isgood)
cocoabengers
# Out:
#                 Name  Alignment_x  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb          1.0            38       100     17          80
# 1         Abe Sapien          1.0            88        14     35          42
# 2           Abin Sur          1.0            50        90     53          64
# 3        Abomination          0.0            63        80     53          90
# 4            Abraxas          0.0            88       100     83          99
# ..               ...          ...           ...       ...    ...         ...
# 595     Yellowjacket          1.0            88        10     12          28
# 596  Yellowjacket II          1.0            50        10     35          28
# 597             Ymir          1.0            50       100     27         100
# 598          Zatanna          1.0            75        10     23          28
# 599             Zoom          0.0            50        10    100          28
#
# ...

# %% [markdown]
# ### good = 1, bad = 0, neutral = 0.5 로 전처리를 해주었다

# %%
plt.figure(figsize = (10,10))
hair = sns.heatmap(cocoabengers[["HairColor", "Alignment_x"]].groupby(["HairColor"]).mean())
plt.show()
cocoabengers[["HairColor", "Alignment_x"]].value_counts()
# Out:
# HairColor         Alignment_x
# -                 1.0            101
# Black             1.0             88
# Blond             1.0             73
# Brown             1.0             47
# -                 0.0             38
# Red               1.0             35
# Black             0.0             33
# No Hair           1.0             29
#                   0.0             26
# Brown             0.0             24
# White             0.0             10
# Auburn            1.0             10
# White             1.0              8
# Red               0.0              8
# Green             1.0              6
# Blond             0.0              6
# Black             0.5              5
# Strawberry Blond  1.0              4
# Brown / White     1.0              3
# Brown             0.5              3
# Silver            1.0              3
# Auburn            0.0              3
# black             1.0              3
# Yellow            1.0              2
# ...

# %% [markdown]
# ### 일부 결측치(-)로 인해서 정확한 데이터는 아니지만 생각보다 대머리 악당의 비율이 높지는 않았다. 그들의 죄라고는 대머리 유전자를 물려받았을 뿐....

# %% [markdown]
# * ### 가정 2: 여러 코믹스 세계관에서 최강자는 대머리인 경우가 많다. 머리카락이 없으면은 파워가 과연 강력할까

# %%
hairpower = sns.catplot(data = cocoabengers, x = "HairColor", y = "Total", kind = "box").set_xticklabels(rotation=90)
hairpower.fig.set_size_inches(15,10)
plt.show()
print("Total mean :",cocoabengers.Total.mean())
print("No Hair mean:", cocoabengers[cocoabengers.HairColor == "No Hair"].Total.mean())
# Out:
# Total mean : 231.365
# No Hair mean: 295.30357142857144

# %%
cocoabengers[cocoabengers.Total > 500].groupby("HairColor")["Total"].count()
# Out:
# HairColor
# -               5
# Black           7
# Black / Blue    1
# Blond           2
# Blue            1
# Brown           1
# No Hair         4
# Red             3
# White           1
# Name: Total, dtype: int64

# %% [markdown]
# ### 머리카락이 없다고 항상 가장 강력한건 아니었다.  평균 보다는 조금더 높은 능력치을 보유하고 있었다. 결측치를 제외한 다른 헤어군에 비해서 Total이 500이 넘는 최강자를 2번째로 많이 보유하고 있다.
# ###### ~~(그들은 모발을 잃고 힘을 많이 얻지는 못했나보다)~~

# %% [markdown]
# ![](https://lh3.googleusercontent.com/proxy/m3d-pT053bfBBQhV3T2BAqnzfgTaASFcvQzBtpmWBzL20CrF2rdMDzZ6C2AnpFKZf_fKBoa6oAANStXiMTdQ0jm4x2Fqv9fZsVUTdAy2NfDCkLy9pd0cZ292sw2WrhIcmbPd10UzmBsJR1kirIlsoBLcn1LoU0cLXcnBBZZST4KOZzRI0nki-xlrxmCrlA)
# 힘내라! 최강자 마쓰 맨 헌터! 보유 머머리국

# %% [markdown]
# ### 3. 코믹스에는 기본적으로 능력을 타고난 강력한 종족이 존재한다. ex) 셀레스티얼, 이터널(타노스), 아스가르드 신족, 크립토니안(슈퍼맨) 실제로 한번 확인해 보자

# %%
racepower = sns.catplot(data = cocoabengers, x = "Race", y = "Total", kind = "box").set_xticklabels(rotation = 90)
racepower.fig.set_size_inches(15,10)

# %% [markdown]
# ### 종족의 따른 차이가 극심한것을 알 수 있다.
# * 크립토니안(슈퍼맨, 조드장군 등등)이나, 우주적존재인 Cosmic Entity(셀레스티얼 등등) 타고난 애들은 쌔다는것을 알 수 있다.
# * 생각보다 신 + 이터널의 평균치가 높지 않았다. case에 따라서 강한신도 있고 약한신도 있기때문으로 보인다.
# * Martian 이 높은 값을 가지고 있긴한데 이건 ~~대머리의 희망~~ 마쓰 맨헌터 단 하나기이 때문에 논외로 하겠다.
