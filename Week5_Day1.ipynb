# %% [markdown]
# <a href="https://colab.research.google.com/github/Zzang-yeah/programmers_kdt_II/blob/week4/Week5_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Day 3 - Django로 자기소개 페이지 만들기
# ##필수 과제 : 아이엠 그라운드 자기소개 하기
# 다음 요청을 처리하는 웹 어플리케이션을 제작해주세요.
# GET / → 자기소개 웹 페이지를 Response
# 이 페이지는 HTML을 이용해서 여러분이 원하는 내용을 작성해주세요.
# ##보너스 과제 : ⭐️아이😊엠 그라운드⛳️ 자기💁‍♀️소개💁‍♂️ 하기⭐️
# CSS나 JavaScript 등을 이용해 자신의 웹 페이지를 더욱 멋있게 만들 수 있습니다.      HTML으로만 된 밋밋한 자기소개 페이지를 꾸며봅시다.
# 이들을 사용하기 위해선 이 파일들이 담긴 경로를 STATIC_URL을 이용해 지정해주어야합니다.

# %%
#views.py
def i_am_ground(request):
    return render(request, "i_am_ground.html")

# %%
#urls.py
from django.contrib import admin
from django.urls import path
from homepage.views import index, coffee_view, i_am_ground

urlpatterns = [
    path('', index),   #http://127.0.0.1:8000/
    path('GET/', i_am_ground),   #http://127.0.0.1:8000/GET/
    path('coffee/', coffee_view),   #http://127.0.0.1:8000/coffee/
    path('admin/', admin.site.urls),    #http://127.0.0.1:8000/admin
]

# %%
<!DOCTYPE html>
<html>
    <head>
        <title>I AM GROUND</title>
    </head>

    <body>
        <h1>I AM GROUND 자기소개하기</h1>
        <p><b>이름?</b>한예지</p>
        <hr style="border : dashed 1px gray;">
        <p><b>좋아하는 거?</b>
        먹기 위해 산다!먹는 게 제일 조아^~^<br>
        초콜릿과 술을 사랑합니다ㅎ</p>
        <p>고앵이 자랑<br>
        저희 집엔 고앵이가 3마리 있습니다 아주 귀엽죠<br>
        <img src="https://postfiles.pstatic.net/MjAyMTA1MjFfMjU4/MDAxNjIxNTU5OTYxMTI1.78FU9Bbdjn0AEB3yKXEmeS1ul70_r7VzJxtoeiwYL1Qg.qpddv4roAxHR-crk9Qo2gt5-U62vi3wqSc4IrmOyIdIg.PNG.cat7892/%EC%B5%9C%EC%A2%85.png?type=w580"></p>
    </body>
</html>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
