# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tft_df = pd.read_csv('./TFT_Challenger_MatchData.csv')
tft_df
# Out:
#               gameId  gameDuration  level  lastRound  Ranked  ingameDuration  \
# 0      KR_4247538593   2142.470703      8         35       1     2134.272217
# 1      KR_4247538593   2142.470703      9         35       2     2134.272217
# 2      KR_4247538593   2142.470703      8         34       3     2073.459229
# 3      KR_4247538593   2142.470703      8         33       4     1998.146729
# 4      KR_4247538593   2142.470703      9         33       5     1986.443237
# ...              ...           ...    ...        ...     ...             ...
# 79994  KR_4357265434   2094.518555      7         33       4     1838.332764
# 79995  KR_4357265434   2094.518555      8         33       5     1837.548096
# 79996  KR_4357265434   2094.518555      9         33       6     1833.472046
# 79997  KR_4357265434   2094.518555      8         31       7     1730.829712
# 79998  KR_4357265434   2094.518555      6         27       8     1480.288086
#
# ...

# %% [markdown]
# 데이터가 너무 많아서 1000경기만 짜름

# %%
tft_df = tft_df.head(8*1000)
tft_df
# Out:
#              gameId  gameDuration  level  lastRound  Ranked  ingameDuration  \
# 0     KR_4247538593   2142.470703      8         35       1     2134.272217
# 1     KR_4247538593   2142.470703      9         35       2     2134.272217
# 2     KR_4247538593   2142.470703      8         34       3     2073.459229
# 3     KR_4247538593   2142.470703      8         33       4     1998.146729
# 4     KR_4247538593   2142.470703      9         33       5     1986.443237
# ...             ...           ...    ...        ...     ...             ...
# 7995  KR_4296027401   2023.627930      8         33       4     1774.929810
# 7996  KR_4296027401   2023.627930      8         31       5     1667.491211
# 7997  KR_4296027401   2023.627930      8         30       6     1613.603394
# 7998  KR_4296027401   2023.627930      7         30       7     1607.925171
# 7999  KR_4296027401   2023.627930      8         30       8     1606.986084
#
# ...

# %%
first_df = tft_df[tft_df['Ranked']==1]
first_df
# Out:
#              gameId  gameDuration  level  lastRound  Ranked  ingameDuration  \
# 0     KR_4247538593   2142.470703      8         35       1     2134.272217
# 8     KR_4247595409   2386.106201      9         41       1     2377.768066
# 16    KR_4247613214   2232.942627      8         38       1     2224.601562
# 24    KR_4247661914   2324.209717      9         38       1     2315.967285
# 32    KR_4247685443   2148.303955      8         37       1     2139.901611
# ...             ...           ...    ...        ...     ...             ...
# 7960  KR_4295989249   1954.190674      8         35       1     1945.939331
# 7968  KR_4296011717   2147.142822      9         38       1     2138.907471
# 7976  KR_4296015584   2157.802734      8         37       1     2149.512695
# 7984  KR_4296019493   1967.296265      8         37       1     1959.054077
# 7992  KR_4296027401   2023.627930      8         38       1     2015.341553
#
# ...

# %%
d=first_df.combination.to_dict()
d
# Out:
# {0: "{'DarkStar': 2, 'Protector': 4, 'Rebel': 1, 'Set3_Celestial': 3, 'Set3_Mystic': 4, 'StarGuardian': 2, 'TemplateTrait': 1}",
#  8: "{'Blaster': 2, 'Demolitionist': 2, 'Mercenary': 2, 'Protector': 1, 'Rebel': 6, 'Set3_Blademaster': 3, 'Set3_Brawler': 1, 'Set3_Celestial': 2, 'Set3_Mystic': 2, 'SpacePirate': 1, 'Starship': 1, 'Valkyrie': 1}",
#  16: "{'Blaster': 2, 'Demolitionist': 2, 'Mercenary': 2, 'Rebel': 6, 'Set3_Blademaster': 2, 'Set3_Mystic': 1, 'SpacePirate': 1, 'Starship': 1, 'Valkyrie': 1}",
#  24: "{'Blaster': 4, 'Chrono': 2, 'Cybernetic': 1, 'Demolitionist': 1, 'Mercenary': 2, 'Rebel': 3, 'Set3_Brawler': 4, 'Set3_Void': 1, 'SpacePirate': 2, 'Starship': 1, 'Valkyrie': 1}",
#  32: "{'DarkStar': 2, 'Protector': 4, 'Rebel': 1, 'Set3_Celestial': 3, 'Set3_Mystic': 4, 'StarGuardian': 2}",
#  40: "{'Blaster': 2, 'Demolitionist': 2, 'Mercenary': 2, 'Rebel': 6, 'Set3_Blademaster': 3, 'Set3_Celestial': 1, 'Set3_Mystic': 2, 'SpacePirate': 1, 'Starship': 1, 'Valkyrie': 2}",
# ...

# %%
d.keys()
# Out:
# dict_keys([0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 264, 272, 280, 288, 296, 304, 312, 320, 328, 336, 344, 352, 360, 368, 376, 384, 392, 400, 408, 416, 424, 432, 440, 448, 456, 464, 472, 480, 488, 496, 504, 512, 520, 528, 536, 544, 552, 560, 568, 576, 584, 592, 600, 608, 616, 624, 632, 640, 648, 656, 664, 672, 680, 688, 696, 704, 712, 720, 728, 736, 744, 752, 760, 768, 776, 784, 792, 800, 808, 816, 824, 832, 840, 848, 856, 864, 872, 880, 888, 896, 904, 912, 920, 928, 936, 944, 952, 960, 968, 976, 984, 992, 1000, 1008, 1016, 1024, 1032, 1040, 1048, 1056, 1064, 1072, 1080, 1088, 1096, 1104, 1112, 1120, 1128, 1136, 1144, 1152, 1160, 1168, 1176, 1184, 1192, 1200, 1208, 1216, 1224, 1232, 1240, 1248, 1256, 1264, 1272, 1280, 1288, 1296, 1304, 1312, 1320, 1328, 1336, 1344, 1352, 1360, 1368, 1376, 1384, 1392, 1400, 1408, 1416, 1424, 1432, 1440, 1448, 1456, 1464, 1472, 1480, 1488, 1496,
# ...

# %%
rich_df = pd.read_csv('./500 richest people 2021.csv')
rich_df
# Out:
#     Rank;Name;Total Net Worth;$ Last Change;$ YTD Change;Country;Industry;;;;
# 0    1;Jeff Bezos;$188B;+$1.68B;-$2.31B ;United Sta...
# 1    2;Elon Musk;$170B;-$2.89B;+$773M ;United State...
# 2    3;Bernard Arnault;$155B;+$892M;+$40.9B ;France...
# 3    4;Bill Gates;$144B;-$1.32B;+$12.2B ;United Sta...
# 4    5;Mark Zuckerberg;$114B;+$203M;+$10.9B ;United...
# ..                                                 ...
# 498  500;Odd Reitan;$5.72B;-$19.9M;+$669M;Norway;Fo...
# 499                                         ;;;;;;;;;;
# 500                                         ;;;;;;;;;;
# 501                                         ;;;;;;;;;;
# 502                                         ;;;;;;;;;;
#
# [503 rows x 1 columns]

# %%
rich_df.Name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-fcf0dc27822c> in <module>
# ----> 1 rich_df.Name()
#
# C:\Users\Public\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Name'
