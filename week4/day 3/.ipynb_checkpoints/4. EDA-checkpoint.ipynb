# %% [markdown]
# # 4. Exploratory Data Analysis
#
# Data Analysis Training with [Titanic Data](https://www.kaggle.com/c/titanic)

# %% [markdown]
# ## 0. Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
titanic_df = pd.read_csv('./train.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 1. Determine the purpose of this analysis and variables in datasets
# -  Who survived in titanic?

# %%
# check 5 datas from the top
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 2. 데이터 전체적으로 살펴보기

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.corr()
# Correlation in NOT causation

#  Correlation : A up, B up
#  Causality : A --> B
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
titanic_df.isnull() # if Null return True
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_df.isnull().sum() # found Null in age, Cabin, Embarked
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 3. 데이터의 개별 속성 파악하기

# %% [markdown]
# ## Survived Column

# %%
# Number of Survived and died people

titanic_df['Survived'].sum()
# Out:
# 342

# %%
titanic_df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
## Bar graph plotting 

sns.countplot(x='Survived',data=titanic_df)
plt.show()

# %% [markdown]
# ## Pclass Column

# %%
titanic_df[['Pclass','Survived']].groupby(['Pclass']).count()
# no matter survived or died
# all number of people in each Pclass
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
titanic_df[['Pclass','Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
# ratio survived
titanic_df[['Pclass','Survived']].groupby(['Pclass']).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
# Heatmap

sns.heatmap(titanic_df[['Pclass','Survived']].groupby(['Pclass']).mean())
plt.plot()
# Out:
# []

# %% [markdown]
# ## Sex column

# %%
titanic_df[['Sex','Survived']]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
titanic_df.groupby(['Sex','Survived']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex    Survived
# female 0                  81      81    81   64     81     81      81    81
#        1                 233     233   233  197    233    233     233   233
# male   0                 468     468   468  360    468    468     468   468
#        1                 109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Sex    Survived
# female 0             6        81
#        1            91       231
# male   0            62       468
#        1            45       109

# %%
titanic_df.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
# Cat plot

sns.catplot(x='Sex',col='Survived',kind='count',data=titanic_df)

# %% [markdown]
# ## Age
# Remind : Null data

# %%
titanic_df.describe()['Age']
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_df[titanic_df.Survived ==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df[titanic_df.Survived ==1]['Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
sns.kdeplot(data=titanic_df[titanic_df.Survived ==1]['Age'],ax=ax)
sns.kdeplot(data=titanic_df[titanic_df.Survived ==0]['Age'],ax=ax)
plt.legend(['Survived','Dead'])
plt.show()

# %% [markdown]
# ## Appendix. Sex+Pclass vs Survived

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',kind='point',data=titanic_df)
plt.show()

# %% [markdown]
# ## Appendix. Sex+Pclass vs Survived

# %%
titanic_df['Age'][titanic_df.Pclass == 1]
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 216, dtype: float64

# %%
titanic_df['Age'][titanic_df.Pclass == 1].plot(kind='kde')
titanic_df['Age'][titanic_df.Pclass == 2].plot(kind='kde')
titanic_df['Age'][titanic_df.Pclass == 3].plot(kind='kde')

plt.legend(['1st class','2nd class','3rd class'])
plt.show()

# %% [markdown]
# ## Mission : It's Your Turn!
#
# ### 1. 본문에서 언급된 Feature를 제외하고 유의미한 Feature를 1개 이상 찾아봅시다.
#
# - Hint : Fare? Sibsp? Parch?
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.
#
#
# ## 미성년자의 형제 수, 보호자 수에 따른 생존확률

# %%
titanic_df[["SibSp", "Survived"]].groupby(['SibSp']).mean()
# 전체 인원의 형제수에 따른 생존확률
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
titanic_df[titanic_df['Age']<18][["SibSp", "Survived"]].groupby(['SibSp']).mean()
# 형제수가 3명이상일때 생존 확률이 급격하게 줄어듬
# Out:
#        Survived
# SibSp
# 0      0.651163
# 1      0.757576
# 2      0.714286
# 3      0.000000
# 4      0.166667
# 5      0.000000

# %%
plt.plot(titanic_df[titanic_df['Age']<18][["SibSp", "Survived"]].groupby(['SibSp']).mean())

# %%
youth_df = titanic_df[titanic_df['Age']<18]
youth_df
# 미성년자인 데이터 추출
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
youth_df.groupby(['Parch']).mean()
#미성년자의 보호자 수에 따른 데이터 대부분 낮은 PClass
#보호자 없이, 혹은 Nanny 와 온경우 평균나이가 
#보호자와 온경우보다 훨씬 높은편이다.
# Out:
#        PassengerId  Survived    Pclass        Age     SibSp       Fare
# Parch
# 0       421.625000  0.500000  2.656250  15.265625  0.312500  18.286334
# 1       471.454545  0.613636  2.590909   6.077727  1.636364  28.245075
# 2       393.833333  0.500000  2.500000   6.937500  2.277778  46.267478
# 3        87.000000  0.000000  3.000000  16.000000  1.000000  34.375000

# %%
youth_df[youth_df['Parch']==3]
# 18세 이하이면서 Parch == 3 --> 자신의 부모와 어린나이이지만 아이가 있는 것으로 추정됨
# Out:
#     PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 86           87         0       3  Ford, Mr. William Neal  male  16.0      1
#
#     Parch      Ticket    Fare Cabin Embarked
# 86      3  W./C. 6608  34.375   NaN        S

# %%
youth_df[['Parch','Survived']].groupby(['Parch']).mean()
# Out:
#        Survived
# Parch
# 0      0.500000
# 1      0.613636
# 2      0.500000
# 3      0.000000

# %%
adult_df = titanic_df[titanic_df['Age']>=18]
adult_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_df[['Parch','Survived']].groupby(['Parch']).mean()
# Out:
#        Survived
# Parch
# 0      0.347648
# 1      0.515152
# 2      0.656250
# 3      0.750000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %%
titanic_df[titanic_df['Age']<6][["SibSp", "Survived"]].groupby(['SibSp']).mean()
# 6세 미만의 유아의 경우 형제수에 따라 극단적인 차이를 보인다
# Out:
#        Survived
# SibSp
# 0        0.9000
# 1        0.9375
# 2        1.0000
# 3        0.0000
# 4        0.2500
# 5        0.0000

# %%
youth_df[youth_df['SibSp']==3]
# skoog 성을 가진 미성년자 아이가 4명인데 SibSp 가 3으로 나오는것으로 보아 데이터 역시 완벽하지 않은것으로 추정된다.
# 대부분 사망한 것으로 데이터 분석에는 큰 차이는 없을 것으로 예상됨
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 7              8         0       3  Palsson, Master. Gosta Leonard    male
# 24            25         0       3   Palsson, Miss. Torborg Danira  female
# 63            64         0       3           Skoog, Master. Harald    male
# 374          375         0       3      Palsson, Miss. Stina Viola  female
# 634          635         0       3              Skoog, Miss. Mabel  female
# 642          643         0       3   Skoog, Miss. Margit Elizabeth  female
# 819          820         0       3    Skoog, Master. Karl Thorsten    male
#
#       Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 7     2.0      3      1  349909  21.075   NaN        S
# 24    8.0      3      1  349909  21.075   NaN        S
# 63    4.0      3      2  347088  27.900   NaN        S
# 374   3.0      3      1  349909  21.075   NaN        S
# 634   9.0      3      2  347088  27.900   NaN        S
# ...

# %%
youth_df[youth_df['SibSp']==5]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 59            60         0       3  Goodwin, Master. William Frederick
# 71            72         0       3          Goodwin, Miss. Lillian Amy
# 386          387         0       3     Goodwin, Master. Sidney Leonard
# 480          481         0       3      Goodwin, Master. Harold Victor
# 683          684         0       3         Goodwin, Mr. Charles Edward
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# 480    male   9.0      5      2  CA 2144  46.9   NaN        S
# 683    male  14.0      5      2  CA 2144  46.9   NaN        S

# %%
youth_df[youth_df['SibSp']==4]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 16            17         0       3                     Rice, Master. Eugene
# 50            51         0       3               Panula, Master. Juha Niilo
# 68            69         1       3          Andersson, Miss. Erna Alexandra
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 164          165         0       3             Panula, Master. Eino Viljami
# 171          172         0       3                     Rice, Master. Arthur
# 182          183         0       3    Asplund, Master. Clarence Gustaf Hugo
# 233          234         1       3           Asplund, Miss. Lillian Gertrud
# 261          262         1       3        Asplund, Master. Edvin Rojj Felix
# 266          267         0       3                Panula, Mr. Ernesti Arvid
# 278          279         0       3                       Rice, Master. Eric
# ...
